# %%
import math
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("Skin_Cancer_Metadata.csv")
df1
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
df2 = pd.read_csv("hmnist_8_8_L.csv")
df2
# Out:
#        pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0            172        182        191        183        180        181
# 1             98        149        170        193        183        162
# 2            165        164        179        172        152        163
# 3            109        159        167        166        163        159
# 4            173        202        210        194        208        248
# ...          ...        ...        ...        ...        ...        ...
# 10010        193        192        191        198        182        191
# 10011         93        139        165        183        188        180
# 10012        165        191        211        227        222        208
# 10013        138        152        154        161        173        177
# 10014        152        152        150        148        156        159
#
#        pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel0055  pixel0056  \
# ...

# %%
merged_df = pd.merge(df1, df2,left_on=None, right_on=None, left_index=False, right_index=False,how='left')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 merged_df = pd.merge(df1, df2,left_on=None, right_on=None, left_index=False, right_index=False,how='left')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
# ...

# %%
print(df1.head())
print(df2.head())
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        172        182        191        183        180        181
# 1         98        149        170        193        183        162
# 2        165        164        179        172        152        163
# 3        109        159        167        166        163        159
# 4        173        202        210        194        208        248
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel0055  pixel0056  \
# 0        165        164        173        192  ...        159        171
# ...

# %%
merged_df = pd.merge(df1, df2, left_on='column_in_df1', right_on='column_in_df2', how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 merged_df = pd.merge(df1, df2, left_on='column_in_df1', right_on='column_in_df2', how='left')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
# ...

# %%
merged_df = pd.merge(df1, df2, on='common_column', how='inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 merged_df = pd.merge(df1, df2, on='common_column', how='inner')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
# ...

# %%
# Concatenate the two datasets vertically (stacking them on top of each other)
merged_df = pd.concat([df1, df2], ignore_index=True)

merged_df
# Out:
#          lesion_id      image_id   dx dx_type   age   sex localization  \
# 0      HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1      HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2      HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3      HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4      HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
# ...            ...           ...  ...     ...   ...   ...          ...
# 20025          NaN           NaN  NaN     NaN   NaN   NaN          NaN
# 20026          NaN           NaN  NaN     NaN   NaN   NaN          NaN
# 20027          NaN           NaN  NaN     NaN   NaN   NaN          NaN
# 20028          NaN           NaN  NaN     NaN   NaN   NaN          NaN
# 20029          NaN           NaN  NaN     NaN   NaN   NaN          NaN
#
#        pixel0000  pixel0001  pixel0002  ...  pixel0055  pixel0056  pixel0057  \
# ...

# %%
merged_df.head(25)
# Out:
#       lesion_id      image_id   dx dx_type   age     sex     localization  \
# 0   HAM_0000118  ISIC_0027419  bkl   histo  80.0    male            scalp
# 1   HAM_0000118  ISIC_0025030  bkl   histo  80.0    male            scalp
# 2   HAM_0002730  ISIC_0026769  bkl   histo  80.0    male            scalp
# 3   HAM_0002730  ISIC_0025661  bkl   histo  80.0    male            scalp
# 4   HAM_0001466  ISIC_0031633  bkl   histo  75.0    male              ear
# 5   HAM_0001466  ISIC_0027850  bkl   histo  75.0    male              ear
# 6   HAM_0002761  ISIC_0029176  bkl   histo  60.0    male             face
# 7   HAM_0002761  ISIC_0029068  bkl   histo  60.0    male             face
# 8   HAM_0005132  ISIC_0025837  bkl   histo  70.0  female             back
# 9   HAM_0005132  ISIC_0025209  bkl   histo  70.0  female             back
# 10  HAM_0001396  ISIC_0025276  bkl   histo  55.0  female            trunk
# 11  HAM_0004234  ISIC_0029396  bkl   histo  85.0  female            chest
# ...

# %%
merged_df.tail(25)
# Out:
#       lesion_id image_id   dx dx_type  age  sex localization  pixel0000  \
# 20005       NaN      NaN  NaN     NaN  NaN  NaN          NaN      216.0
# 20006       NaN      NaN  NaN     NaN  NaN  NaN          NaN      158.0
# 20007       NaN      NaN  NaN     NaN  NaN  NaN          NaN      100.0
# 20008       NaN      NaN  NaN     NaN  NaN  NaN          NaN      174.0
# 20009       NaN      NaN  NaN     NaN  NaN  NaN          NaN      150.0
# 20010       NaN      NaN  NaN     NaN  NaN  NaN          NaN      186.0
# 20011       NaN      NaN  NaN     NaN  NaN  NaN          NaN      110.0
# 20012       NaN      NaN  NaN     NaN  NaN  NaN          NaN      148.0
# 20013       NaN      NaN  NaN     NaN  NaN  NaN          NaN      159.0
# 20014       NaN      NaN  NaN     NaN  NaN  NaN          NaN      198.0
# 20015       NaN      NaN  NaN     NaN  NaN  NaN          NaN      124.0
# 20016       NaN      NaN  NaN     NaN  NaN  NaN          NaN      159.0
# ...

# %%
merged_df.mean()
# Out:
# C:\Users\Trisha\AppData\Local\Temp\ipykernel_17556\1393354743.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   merged_df.mean()
# age           51.863828
# pixel0000    156.511533
# pixel0001    167.292461
# pixel0002    171.177933
# pixel0003    171.134199
#                 ...
# pixel0060    167.451423
# pixel0061    167.852322
# pixel0062    164.511233
# pixel0063    152.323615
# label          3.720919
# Length: 66, dtype: float64

# %%
merged_df.fillna(merged_df.mean(), inplace=True)
# Out:
# C:\Users\Trisha\AppData\Local\Temp\ipykernel_17556\2167644475.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   merged_df.fillna(merged_df.mean(), inplace=True)
